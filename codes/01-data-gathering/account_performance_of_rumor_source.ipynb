# %%
import json
import tweepy
import pandas as pd

# %%
data=pd.read_csv("../../data/00-raw-data/rumor_manually.csv",encoding='windows-1252')
data=data.loc[:,"text":]
data.drop_duplicates(subset='twitter_id', keep='first',inplace=True)

# %%
# load key
consumer_key = "OA4CTZkyLwMOg08PlFt0goCNC"
consumer_secret = "8k59TeAGeqlHXjf4wjOjrKLYXpEvutuRgDjLxVxm5R7uC5wB0q"
access_token = "1177285260242874368-QoMZGUj2TsbkXyPQ5o0pu5iFrFT72q"
access_token_secret = "6JWjo6Ro4RmqIBFLjOop9QW1FCgHZltRTz8EIsj9UiMOE"
bearer_token = "AAAAAAAAAAAAAAAAAAAAAISeXgEAAAAANwEgP0gtkLS%2Bjv9qCa3pIB3o1xs%3D98KYFXJI2DYHslg3StyrI2h9aB0w8PYq8iJyGS6Vdwsrhgkt7r"

#get authorization
auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api=tweepy.API(auth)

# %%
data.twitter_id.tolist()
# Out:
# [105631171,
#  112684779,
#  739187198495477760,
#  706551827672621058,
#  2805007468,
#  259001548,
#  42278624,
#  1556388209671737346,
#  767788995962998784,
#  5514192,
#  255986116,
#  2459542196,
#  8940342,
#  2525149488,
#  3094974153,
#  806344552718045184,
#  18342379,
#  39344374,
#  1536373979790835713,
#  926164634570067968,
#  1447493161614553089,
#  32300682,
#  1355604149619077121,
#  1467566088,
#  149346219,
#  1354582871223185408,
#  977639698960191489,
#  754718787237281792,
#  878284831]

# %%
#use tweepy to find the information of rumor sources
respond=api.lookup_users(user_id=data.twitter_id.tolist())
# get the informatino from the structured data and store what we need in a list 
location=[]
followers_count=[]
friends_count=[]
description=[]
for item in respond:
    location.append(item._json["location"])
    followers_count.append(item._json["followers_count"])
    friends_count.append(item._json["friends_count"])
    description.append(item._json["description"])

# %%
#fill the columns with values
data["friends_count"]=friends_count
data["location"]=location
data["followers_count"]=followers_count
#create a new column
data["description"]=description

# %%
#save the csv
data.to_csv("../../data/01-modified-data/cleaned_rumor_manually.csv",index=False)

# %%
# Out:
#                                                  text  \
# 0   is that you tome hanks?...how about we keep am...
# 1   After the dreadful hurricane in Florida @VP  K...
# 2   Heartbreaking! Iranian father who promised to ...
# 3   my dad just sent me this video from Naples Flo...
# 4   Omg so all funerals due on the 19 th have been...
# 5   BIDEN ADMITS TO VOTER FRAUD! @JoeBiden brags a...
# 6   Troglodyte thinks escalation. Talked about thi...
# 7   Massive protest by Russians in St Petersburg a...
# 8   NEWS: Reps Liz Cheney and Zoe Lofgren have pro...
# 9   In Brazil, an invasion of crocodiles that have...
# 10  Border btw #Russia - #Finland after #Putin"s p...
# 11  Situation at Finland's borders has not changed...
# 12  Gov. Greg Abbott and Democratic challenger Bet...
# 14  The National Institute of Health and CDC now s...
# 15  At  @defcon hacking conference and just learne...
# 16  BREAKING: D.C. has banned unvaccinated student...
# 17  BREAKING: California Gov. Gavin Newsom conside...
# 18  So in Los Angles they just disqualified almost...
# 19  BREAKING In order to safeguard democracy, Cong...
# 20  NEW: Donald is fundraising by giving us ¡°nucl...
# 21  Joey! Hey Joey! Look at all the people gathere...
# 22   THREE Trillium Health Partners-Mississauga Ho...
# 23  The original Covid had an Ro value of 3.3, mea...
# 24  Breaking news Pennsylvania chooses not to acce...
# 25  BOMBSHELL: Biological Study PROVES Pfizer mRNA...
# 26  December 2021: Reuters fact check - no evidenc...
# 27  NASA has announced that CO-2 emissions have ze...
# 28  #BREAKING Farmers in the #Netherlands have jus...
# 29  BREAKING NEWS: Republican Senate Minority Lead...
#
#                           location  friends_count  followers_count  \
# 0                                           13006            31014
# 1                           London          31163            33758
# 2                          Nature            4441             9363
# 3                                              70               29
# 4                                            4795             3928
# 5                                            2423          2776281
# 6                     New York, NY            361            44542
# 7                                               4               21
# 8                                            2523           500381
# 9                  Los Angeles, CA         742632           898388
# 10                             xxx           1010            79111
# 11                         Finland            331            36684
# 12                     Houston, TX            161           700464
# 14                          Canada           2274            30947
# 15               San Francisco, CA           7706            88928
# 16                    Florida, USA            122           523336
# 17                      Austin, TX           1347            50791
# 18                                           1694          8525714
# 19                                             75            21645
# 20                   San Diego, CA           8662           371169
# 21                                           4988             2872
# 22     Province of Ontario, Canada            788             1127
# 23  Planet Earth, Milky Way Galaxy           4438             5776
# 24     conservative libertarianism           4950             4097
# 25                   Boalsburg, Pa            623            70262
# 26                                            738             7978
# 27                      Medina, OH          24359            24497
# 28                                            358            50253
# 29                   United States          24198           494413
#
#                       screen_name  retweet_count  favorite_count  label  \
# 0                   helen henning            763            4208  rumor
# 1                  David Atherton            198             297  rumor
# 2                     Shukri Hamk           9589           30927  rumor
# 3   the worlds foremost authority            933            3681  rumor
# 4                   Carolyn Brown           3381           26141  rumor
# 5                Kayleigh McEnany          20227           46089  rumor
# 6                  Michael Taylor             13              92  rumor
# 7                        theivall           1140            3462  rumor
# 8                 Really American          20414           58418  rumor
# 9                   Ken Rutkowski          24194          168604  rumor
# 10                      C4H10FO2P            167             576  rumor
# 11               Rajavartiolaitos           1880            5181  rumor
# 12              Houston Chronicle             50             173  rumor
# 14                    Tom Quiggin             13              16  rumor
